# %% [markdown]
# # ¿Qué es la inteligencia artificial?

# %% [markdown]
# La inteligencia artificial es una analogía derivada de las ciencias computacionales que elude al proceso de racionalización de un humano (ser biológico) para realizar una tarea o acción específica, la diferencia radica en que dicha tarea o acción es implementada mediante el uso de un ordenador. Este proceso de racionalización incluye la detección de patrones, solución de problemas y aprendizaje autónomo. Para lograr que este análogo funcione se requieren de procesos estadísticos principalmente al igual de aprendizaje automático en varios casos. La inteligencia artificial se ha fragmentado en subcampos como el de aprendizaje automático (Machine Learning) y el aprendizaje profundo (Deep Learning).

# %% [markdown]
# # ¿Qué es la inteligencia artificial estrecha, también llamada débil?

# %% [markdown]
# Básicamente refiere a como puede superar en términos de precisión un sistema informático en una determinada tarea a un ser humano, ejemplos son asistentes personales y vehículos autónomos, es la IA que se usa actualmente en todos los procesos de "pensamiento" automático por parte de ordenadores.

# %% [markdown]
# #¿Qué es la inteligencia artificial fuerte o también llamada general? ¿y la superinteligencia artificial?

# %% [markdown]
# Es una ramificación teórica de la inteligencia artificial que simula el pensamiento humano, debido a que podría realizar tareas más complejas, tendría la capacidad de imaginar y ser creativa, vincular aprendizajes para resolver otros de forma más óptima, sería capaz de emitir juicios y de superar a la inteligencia artificial débil. La superinteligencia artificial sería capaz de superar la mente de un humano, porque podría complementar su creatividad científica, aumentar los conocimientos generales y todas las habilidades sociales con las que nos desenvolvemos los seres humanos, incluso podría mejorar la capacidad de comunicación de ideas.

# %% [markdown]
# #¿Qué es el aprendizaje supervisado? ¿Cuáles serían algunos ejemplos de este tipo de aprendizaje usados actualmente por las empresas?

# %% [markdown]
# Es una ramificación de Machine Learning la cuál busca datos estructurados o etiquetados como entrada y con esto aprende, por ejemplo si quieres que reconozca algún objeto como un vaso o una botella lo tienes que alimentar con imágenes etiquedas del objeto, es importante enfatizar que esta necesita de más asistencia humana para poder aprender, puesto que una persona debe de anteponer cierto orden jerarquico para que la IA se desarrolle. Netflix para personalizar el contenido de los usuarios para la selección de series o películas. Captcha de google igualmente usa de datos etiquetados para aprender y diferenciar cuentas falsas.

# %% [markdown]
# #¿Qué es el aprendizaje no supervisado y cuáles serían algunos ejemplos usados en las empresas?

# %% [markdown]
# De igual forma es una rama de ML pero la diferencia radica en que este no requiere de datos etiquetados como entrada, por lo tanto, esta misma se encarga de clasificarlos, el aprendizaje no supervisado es capaz de encontrar patrones y de ordenar los datos de entrada. Existe la analogía del niño que está en desarrollo el cuál va aprendiendo conforme va creciendo al usar detección de patrones, figuras, etc. Para analizar detección de correos de spam de Google o los chatbots de Facebook. Twitter, Snapchat e Instagram que manejan grandes volúmenes de datos sin etiquetar.

# %% [markdown]
# #Enuncia cuatro beneficios que le pueden traer a una empresa que desea hacer uso de la IA.

# %% [markdown]
# Automatización de procesos industriales, por ejemplo al poder inspeccionar muchos datos de manera más rápida esta puede asesorar en la mejora e implementanación de procesos industriales, reducción de errores pues la Ia puede procesar mayor cantidad de datos en menor tiempo y puede detectar errores de manera más eficiente que un humano. No cuenta con horarios preestablecidos, es decir puede trabajar sin descansar, puede desarrollar tareas continúas. Puede ayudar en analizar gran númerp de datos y hacer modelados de manera predictiva para potenciar los avances.

# %% [markdown]
# Fuente externa:
#
# https://riunet.upv.es/bitstream/handle/10251/153230/Baviera%20-%20T%C3%A9cnicas%20para%20el%20an%C3%A1lisis%20del%20sentimiento%20en%20Twitter%3A%20Aprendizaje%20Autom%C3%A1tico%20Supervisad....pdf?sequence=1
#
# https://www.ruhr-uni-bochum.de/lmi/darnstdt/captchas_icml2014.pdf
