# %%
#################################################################################################################################################################################################

# %% [markdown]
# ## **Módulo 1**

# %% [markdown]
# Estadísticamente Python es el lenguaje más usado de programación, es fácil de aprender, dinámico, orientado a objetos y particularmente bueno para programación en web, me atreveré a segmentar estas notas con base en los cuatro módulos del curso. Cada sección estará subdivida con comentarios propios y de la misma plataforma.

# %% [markdown]
# Una declaración o instrucción es un comando que la computadora correrá, la declaración más simple que se puede hacer es mediante el uso del comando *print( )*, en donde "print" es el comando y lo que encierra entre paréntesis es el argumento o mejor dicho, lo que se desea imprimir en forma de texto.

# %%
# Comando imprimir: ¡Hola mundo!
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# Si existe un error sintaxis entonces uno tendrá un error, es decir, Python no entenderá la orde que se le dio. Si en vez de poner *print( )* uno pone *frint( )* Python indicará que hay error de sintaxis. Existe otro tipo de error, el error de semántica es cuando tu lógica esta mal.

# %%
# print('Hello Python 102') en vez de 101 generará error de semántica
print('Hello Python 101')
# Out:
# Hello Python 101

# %% [markdown]
# *Types*, o tipos es la forma que tiene Python para representar diferentes tipos de datos.
#
# Pueden ser de tipo entero 𝐙 como el caso de 11. **(int)**
#
# Reales ℜ como el caso de 21.213. **(float)**
#
# O de tipo string (palabras). **(str)**
#
# La función **type( )** te regresa el tipo de commando que Python esta utilizando: type(11) → int.

# %%
type(3.1415962)
# Out:
# float

# %%
type(11)
# Out:
# int

# %% [markdown]
# Los enteros pueden ser positivos o negativos, pero tienen un rango finito.
# Los flotantes son números entre los números enteros. Se puede convertir de un tipo entero a un tipo flotante mediante las funciones *float(), int(), str()* ejemplo:

# %%
str(4.5)
# Out:
# '4.5'

# %%
float(3)
# Out:
# 3.0

# %%
# En este caso, se pierde información de los números decimales al pasar una cantidad flotante a entera
int(4.5)
# Out:
# 4

# %% [markdown]
# No se permite utilizar los comandos *float()* ni *int()* con variables de tipo *str* puesto que estas manejan texto y no números; sin embargo se puede convertir de variables tipo *float, int* a *str*.

# %%
# La salida determina la representación en formato texto del número entero 6
str(6)
# Out:
# '6'

# %% [markdown]
# Existen también las cantidades Booleanas, es decir 1's y 0's o verdadero y falso. Al usar el comando *type(True)* este nos devuelve el tipo *bool*. Si usamos el comando int en el comando booleano tipo true nos regresará un 1, y viceversa si usamo el comando bool con un entero 1 nos regresará true.

# %%
int(True)
# Out:
# 1

# %%
bool(0)
# Out:
# False

# %% [markdown]
# Las expresiones son operaciones que Python puede realizar, por ejemplo: operaciones básicas aritmética como la adición:

# %%
43+60+16+41
# Out:
# 160

# %% [markdown]
# Se le denomina a los números operandos y a los símbolos operadores; además de la adición uno puede restar, dividir, multiplicar, potenciar y modular
# *+,-,/,*,// (división entera)*.
# Python usa convenciones matemáticas para obtener las operaciones por medio de jerarquización.
#
# La variables sirven para guardar valores:
# **x = 1** es decir le asignas a la variable *x* la cantidad de *1*, se puede ver como una operación que se realiza de derecha a izquierda, puesto que a *1* lo almacenas dentro de un símbolo existente dentro de la memoria de la computadora en *x*, cabe recalcar que puedes sobreescribir la cantidad si se vuelve usar *x*. Por ejemplo si yo asignará x=1 y luego en algún otra parte del código asigno x=10, x se sobreescribirá y su valor final será el último escrito, es decir, 10.

# %%
60*23+15
# Out:
# 1395

# %%
54%6
# Out:
# 0

# %%
x=1
x=10
print('x es igual a',x)
# Out:
# x es igual a 10

# %% [markdown]
# Se puede operar sobre las mismas variables y llamar a otra variable para almacenar el resultado o renombrar la misma variable para que contenga una *'actualización'* en su valor, por eso el último valor en el historial es el que importa, por ejemplo:

# %%
x = 5+78*9 # se almacena la cantidad dada por esta pequeña función
y = x/6 # se divide el resultado de las operaciones en x en 6 partes y se almacena en y
print('x vale:',x)
print('y vale:',y) # se imprimen los valores de x y y
# Out:
# x vale: 707
# y vale: 117.83333333333333

# %%
x = 5+78*9
x = x/6 # reescribimos (actualizamos) x al operar el resultado antiguo de x entre 6
print('x vale:',x)
# Out:
# x vale: 117.83333333333333

# %% [markdown]
# Ejemplo mostrado con relación a la transformación de minutos a horas:

# %%
total_min = 43+42+57
total_hr = total_min/60
print('Conversión de horas a minutos:',total_hr)
# Out:
# Conversión de horas a minutos 2.3666666666666667

# %% [markdown]
# Evidencia del primer laboratorio![image.png](data:image/png;base64,...)

# %%
import sys
print(sys.version)
# Out:
# 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Strings** - en Python los strings son una secuencia de carácteres entre dos comillas, pueden ser una o dos comillas ('',""), también pueden ser carácteres especiales. Se puede asignar un string a una variable, se puede pensar en un string como en una secuencia y cada elemento puede ser accesado:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se puede accesar a cada carácter mediante el uso de índices, empezando por el 0, se puede acceder al 6 o al 14.
# También se pueden usar índices negativos para representar un string. Para esto se usa el comando: **Name[-1]** o similar.
#
# Es posible formar vectores de *n* elementos mediante un conjunto de strings: **Name[0:4]** te devuelve un conjunto de los índices que forman el string mediante representación: **[0123]** en el caso de la imagen superior es la palabra **Mich**.
#
# Tambien podemos segmentar a través de slicing, por ejemplo **Name[::2]** regresa cada segundo valor del índice que conforma el string, de igual forma se puede delimitar de que índice hasta que índice se require cortar de dos en dos **Name[0:5:2]** del índice cero al cinco en pasos de dos en dos → Mca

# %% [markdown]
# El comando **len( )** te da el largo del vector de índices de todo el string.
#
# El comando para concatenar o unir dos strings (pegar uno de lado del otro) se usa mediante un signo +. **Name + 'is the best'** → Michael Jackson is the best.
#
# Se puede replicar el string al multiplicarlo por *n*-número de veces:

# %%
Name = 'Michael Jackson '
rep = 3*Name
rep
# Out:
# 'Michael Jackson Michael Jackson Michael Jackson '

# %% [markdown]
# No es posible cambiar el valor del string mediante el reemplazo de alguna de los carácteres que contiene el índice: **Name[0]=J** es incorrecto, pero sí se puede añadir más detalles mediante la concatenación.
#
# La contra diagonal \ te ayuda a implementar una secuencia de escape, por ejemplo: \n te representa una nueva línea.

# %%
print('Michael Jackson \n is the best')
# Out:
# Michael Jackson
#  is the best

# %% [markdown]
# Similarmente la contradiagonal \t representa un espaciado

# %%
print('Michael Jackson \t is the best')
# Out:
# Michael Jackson 	 is the best

# %% [markdown]
# Si se requiere poner una contradiagonal dentro de un string se debe de colocar dos veces la contradiagonal \\

# %%
print('Michael Jackson \\ is the best')
# Out:
# Michael Jackson \ is the best

# %% [markdown]
# Cuando aplicamos un método al string *A*, obtenemos como salida un string *B*. Como ejemplo podemos convertir los carácteres de minúsculas a mayúsculas mediante la función **.upper()** al final del string:

# %%
A = 'Thriller is the sixth studio album'
B = A.upper()
B
# Out:
# 'THRILLER IS THE SIXTH STUDIO ALBUM'

# %% [markdown]
# Podemos intercambiar mediante el comando **.replace()** un segmento dentro de otro string

# %%
A = 'Thriller is the sixth studio album'
B = A.replace('Thriller','Trailer')
B
# Out:
# 'Trailer is the sixth studio album'

# %% [markdown]
# Podemos encontrar el primer índice de una oración o frase mediante el comando **.find()**

# %%
Name = 'Michael Jackson'
Name.find('ch')
# Out:
# 2

# %% [markdown]
# Si el sub-strinf no se encuentra dentro del string el resultado es -1, refiriendose a que no existe dicho segmento.

# %%
name = 'Lizz'
print(name[0:2])
# Out:
# Li

# %% [markdown]
# Nota importante arriba si usas los índices adecuadamente Lizz tiene 4 índices pero que corren de 0 a 3; sin embargo, al extraer de 0:2 el último no está incluido dentro de la salida, es decir, te incluye solamente: [0 1] = Li. Tiene sentido porque si solamente definimos hasta la posición dos y los índices siguen la regla de *pos-1* entonces el largo debe ser de dos carácteres y no de tres como sugiere el índice [0 1 2]

# %% [markdown]
# Laboratorio 2 evidencia:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
###############################################################################################################################################################################################

# %% [markdown]
# ##Módulo 2
